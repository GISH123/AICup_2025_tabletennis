# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelBinarizer

# === Feature Engineering per swing ===
def extract_features_from_swing(swing):
    # swing: np.array of shape (N, 6)
    Ax, Ay, Az = swing[:, 0], swing[:, 1], swing[:, 2]
    Gx, Gy, Gz = swing[:, 3], swing[:, 4], swing[:, 5]
    
    acc_mag = np.linalg.norm(swing[:, :3], axis=1)
    gyro_mag = np.linalg.norm(swing[:, 3:], axis=1)

    feats = {
        'Ax_mean': Ax.mean(), 'Ax_std': Ax.std(),
        'Ay_mean': Ay.mean(), 'Ay_std': Ay.std(),
        'Az_mean': Az.mean(), 'Az_std': Az.std(),
        'Gx_mean': Gx.mean(), 'Gx_std': Gx.std(),
        'Gy_mean': Gy.mean(), 'Gy_std': Gy.std(),
        'Gz_mean': Gz.mean(), 'Gz_std': Gz.std(),
        'acc_mag_mean': acc_mag.mean(),
        'gyro_mag_mean': gyro_mag.mean(),
        'acc_vs_gyro_ratio': acc_mag.mean() / (gyro_mag.mean() + 1e-6),
        'acc_early_mean': acc_mag[:len(acc_mag)//2].mean(),
        'acc_late_mean': acc_mag[len(acc_mag)//2:].mean(),
        'acc_early_late_ratio': acc_mag[:len(acc_mag)//2].mean() / (acc_mag[len(acc_mag)//2:].mean() + 1e-6)
    }
    return feats

# %%
from tqdm import tqdm

def process_file_to_swing_features(file_path: Path, cut_points: list[int], mode: int) -> pd.DataFrame:
    with open(file_path, 'r') as f:
        lines = f.readlines()[1:]  # skip header

    data = [list(map(int, line.strip().split())) for line in lines if len(line.strip().split()) == 6]
    data = np.array(data)

    swings = [data[cut_points[i]:cut_points[i+1]] for i in range(len(cut_points) - 1)]

    swing_rows = []
    for i, swing in enumerate(swings):
        row = extract_features_from_swing(swing)
        row['swing_id'] = i
        row['file_id'] = int(file_path.stem)
        # one-hot encode mode_1 ~ mode_10
        for m in range(1, 11):
            row[f'mode_{m}'] = 1 if mode == m else 0
        swing_rows.append(row)

    return pd.DataFrame(swing_rows)

# %%
import numpy as np

def build_full_swing_dataset(data_folder: Path, info_df: pd.DataFrame) -> pd.DataFrame:
    all_rows = []
    for file_path in tqdm(sorted(data_folder.glob("*.txt")), desc="⛏ Extracting swings"):
        uid = int(file_path.stem)
        row = info_df[info_df['unique_id'] == uid]
        if row.empty or pd.isna(row['cut_point'].values[0]):
            continue
        cut_points_str = row['cut_point'].values[0]
        cut_points = np.fromstring(cut_points_str.strip("[]"), sep=' ', dtype=int).tolist()
        if len(cut_points) < 2:
            continue
        mode = int(row['mode'].values[0])
        df = process_file_to_swing_features(file_path, cut_points, mode)
        df['gender'] = row['gender'].values[0]
        df['hold racket handed'] = row['hold racket handed'].values[0]
        df['play years'] = row['play years'].values[0]
        df['level'] = row['level'].values[0]
        all_rows.append(df)
    return pd.concat(all_rows, ignore_index=True)

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder

def train_lightgbm_per_label(df, target_col, is_multiclass=False, n_splits=9):
    print(f"\n📚 Training LightGBM for {target_col}...")
    
    drop_cols = ['file_id', 'swing_id', 'gender', 'hold racket handed', 'play years', 'level']
    X = df.drop(columns=drop_cols)

    y_raw = df[target_col].values
    le = LabelEncoder()
    y = le.fit_transform(y_raw)

    if is_multiclass:
        params = {
            'objective': 'multiclass',
            'metric': 'multi_logloss',
            'learning_rate': 0.05,
            'verbosity': -1,
            'num_class': len(np.unique(y)),
            'seed': 42
        }
    else:
        params = {
            'objective': 'binary',
            'metric': 'auc',
            'learning_rate': 0.05,
            'verbosity': -1,
            'seed': 42
        }

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    oof_preds = np.zeros((len(X), len(np.unique(y))) if is_multiclass else len(X))
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        print(f"▶ Fold {fold}")
        dtrain = lgb.Dataset(X.iloc[train_idx], label=y[train_idx])
        dval = lgb.Dataset(X.iloc[val_idx], label=y[val_idx])

        model = lgb.train(
            params,
            dtrain,
            num_boost_round=1000,
            valid_sets=[dtrain, dval],
            callbacks=[lgb.early_stopping(50), lgb.log_evaluation(100)]
        )

        preds = model.predict(X.iloc[val_idx])
        oof_preds[val_idx] = preds

    # Evaluate
    if is_multiclass:
        score = roc_auc_score(y, oof_preds, multi_class='ovr', average='macro')
    else:
        score = roc_auc_score(y, oof_preds)

    print(f"✅ {target_col} AUC = {score:.5f}")
    return model, le

# %%
from pathlib import Path
import pandas as pd

# Load official cut points
train_info = pd.read_csv("39_Training_Dataset/train_info.csv")
data_folder = Path("39_Training_Dataset/train_data")

# Generate swing-level dataframe (~27 rows per file)
swing_df = build_full_swing_dataset(data_folder, train_info)

# (Optional) Save to CSV for reuse
# swing_df.to_csv("swing_df.csv", index=False)
# Out:
# ⛏ Extracting swings: 100%|█████████████████████████████████████████████████████████| 1955/1955 [00:22<00:00, 87.31it/s]

# %%
# swing_df = build_full_swing_dataset(...)
model_gender, le_gender = train_lightgbm_per_label(swing_df, 'gender', is_multiclass=False, n_splits=9)
model_hand, le_hand = train_lightgbm_per_label(swing_df, 'hold racket handed', is_multiclass=False, n_splits=9)
model_years, le_years = train_lightgbm_per_label(swing_df, 'play years', is_multiclass=True, n_splits=9)
model_level, le_level = train_lightgbm_per_label(swing_df, 'level', is_multiclass=True, n_splits=9)
# Out:
# 📚 Training LightGBM for gender...
# ▶ Fold 0
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0.985913	valid_1's auc: 0.974849
# [200]	training's auc: 0.993991	valid_1's auc: 0.983132
# [300]	training's auc: 0.996925	valid_1's auc: 0.986008
# [400]	training's auc: 0.998509	valid_1's auc: 0.987339
# [500]	training's auc: 0.999259	valid_1's auc: 0.988258
# [600]	training's auc: 0.999649	valid_1's auc: 0.988812
# [700]	training's auc: 0.999858	valid_1's auc: 0.989217
# [800]	training's auc: 0.999942	valid_1's auc: 0.989546
# [900]	training's auc: 0.999981	valid_1's auc: 0.989894
# [1000]	training's auc: 0.999994	valid_1's auc: 0.990058
# Did not meet early stopping. Best iteration is:
# [998]	training's auc: 0.999993	valid_1's auc: 0.990059
# ▶ Fold 1
# Training until validation scores don't improve for 50 rounds
# [100]	training's auc: 0
# ▶ Fold 1
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.316089	valid_1's multi_logloss: 0.342345
# [200]	training's multi_logloss: 0.233128	valid_1's multi_logloss: 0.279638
# [300]	training's multi_logloss: 0.185205	valid_1's multi_logloss: 0.245556
# [400]	training's multi_logloss: 0.150042	valid_1's multi_logloss: 0.223023
# [500]	training's multi_logloss: 0.125304	valid_1's multi_logloss: 0.209238
# [600]	training's multi_logloss: 0.103888	valid_1's multi_logloss: 0.197734
# [700]	training's multi_logloss: 0.0870125	valid_1's multi_logloss: 0.188733
# [800]	training's multi_logloss: 0.0738079	valid_1's multi_logloss: 0.182291
# [900]	training's multi_logloss: 0.0624528	valid_1's multi_logloss: 0.177175
# [1000]	training's multi_logloss: 0.0526554	valid_1's multi_logloss: 0.172438
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0526554	valid_1's multi_logloss: 0.172438
# ▶ Fold 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.315985	valid_1's multi_logloss: 0.338568
# [200]	training's multi_logloss: 0.230971	valid_1's multi_logloss: 0.274317
# [300]	training's multi_logloss: 0.183242	valid_1's multi_logloss: 0.243004
# [400]	training's multi_logloss: 0.149622	valid_1's multi_logloss: 0.223051
# [500]	training's multi_logloss: 0.124114	valid_1's multi_logloss: 0.209397
# [600]	training's multi_logloss: 0.103602	valid_1's multi_logloss: 0.198801
# [700]	training's multi_logloss: 0.0867583	valid_1's multi_logloss: 0.190924
# [800]	training's multi_logloss: 0.0734083	valid_1's multi_logloss: 0.185191
# [900]	training's multi_logloss: 0.0620078	valid_1's multi_logloss: 0.180183
# [1000]	training's multi_logloss: 0.0519956	valid_1's multi_logloss: 0.175757
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0519956	valid_1's multi_logloss: 0.175757
# ▶ Fold 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.314253	valid_1's multi_logloss: 0.343933
# [200]	training's multi_logloss: 0.232225	valid_1's multi_logloss: 0.280471
# [300]	training's multi_logloss: 0.183202	valid_1's multi_logloss: 0.247346
# [400]	training's multi_logloss: 0.148108	valid_1's multi_logloss: 0.226208
# [500]	training's multi_logloss: 0.122638	valid_1's multi_logloss: 0.213233
# [600]	training's multi_logloss: 0.101729	valid_1's multi_logloss: 0.203133
# [700]	training's multi_logloss: 0.0849374	valid_1's multi_logloss: 0.195476
# [800]	training's multi_logloss: 0.0711876	valid_1's multi_logloss: 0.189471
# [900]	training's multi_logloss: 0.0603721	valid_1's multi_logloss: 0.185152
# [1000]	training's multi_logloss: 0.050903	valid_1's multi_logloss: 0.181337
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.050903	valid_1's multi_logloss: 0.181337
# ▶ Fold 4
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.313481	valid_1's multi_logloss: 0.346022
# [200]	training's multi_logloss: 0.23129	valid_1's multi_logloss: 0.281221
# [300]	training's multi_logloss: 0.184474	valid_1's multi_logloss: 0.2492
# [400]	training's multi_logloss: 0.148944	valid_1's multi_logloss: 0.227418
# [500]	training's multi_logloss: 0.121839	valid_1's multi_logloss: 0.212156
# [600]	training's multi_logloss: 0.102309	valid_1's multi_logloss: 0.201997
# [700]	training's multi_logloss: 0.0853329	valid_1's multi_logloss: 0.193328
# [800]	training's multi_logloss: 0.0712412	valid_1's multi_logloss: 0.18589
# [900]	training's multi_logloss: 0.0598491	valid_1's multi_logloss: 0.181168
# [1000]	training's multi_logloss: 0.0504806	valid_1's multi_logloss: 0.176963
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0504806	valid_1's multi_logloss: 0.176963
# ▶ Fold 5
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.312968	valid_1's multi_logloss: 0.344596
# [200]	training's multi_logloss: 0.230905	valid_1's multi_logloss: 0.283326
# [300]	training's multi_logloss: 0.185149	valid_1's multi_logloss: 0.254117
# [400]	training's multi_logloss: 0.151533	valid_1's multi_logloss: 0.234644
# [500]	training's multi_logloss: 0.124844	valid_1's multi_logloss: 0.220345
# [600]	training's multi_logloss: 0.103224	valid_1's multi_logloss: 0.209657
# [700]	training's multi_logloss: 0.0872117	valid_1's multi_logloss: 0.20278
# [800]	training's multi_logloss: 0.0732396	valid_1's multi_logloss: 0.196847
# [900]	training's multi_logloss: 0.0619881	valid_1's multi_logloss: 0.192929
# [1000]	training's multi_logloss: 0.0523143	valid_1's multi_logloss: 0.189436
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0523143	valid_1's multi_logloss: 0.189436
# ▶ Fold 6
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.314066	valid_1's multi_logloss: 0.340532
# [200]	training's multi_logloss: 0.231592	valid_1's multi_logloss: 0.278864
# [300]	training's multi_logloss: 0.184428	valid_1's multi_logloss: 0.249236
# [400]	training's multi_logloss: 0.150503	valid_1's multi_logloss: 0.229932
# [500]	training's multi_logloss: 0.123689	valid_1's multi_logloss: 0.215442
# [600]	training's multi_logloss: 0.103588	valid_1's multi_logloss: 0.204977
# [700]	training's multi_logloss: 0.0861517	valid_1's multi_logloss: 0.196174
# [800]	training's multi_logloss: 0.0722981	valid_1's multi_logloss: 0.189371
# [900]	training's multi_logloss: 0.0607051	valid_1's multi_logloss: 0.184009
# [1000]	training's multi_logloss: 0.0510917	valid_1's multi_logloss: 0.180174
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0510917	valid_1's multi_logloss: 0.180174
# ▶ Fold 7
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.314299	valid_1's multi_logloss: 0.355107
# [200]	training's multi_logloss: 0.230065	valid_1's multi_logloss: 0.290286
# [300]	training's multi_logloss: 0.182419	valid_1's multi_logloss: 0.258208
# [400]	training's multi_logloss: 0.147745	valid_1's multi_logloss: 0.237233
# [500]	training's multi_logloss: 0.122513	valid_1's multi_logloss: 0.224451
# [600]	training's multi_logloss: 0.102562	valid_1's multi_logloss: 0.213135
# [700]	training's multi_logloss: 0.0859024	valid_1's multi_logloss: 0.204858
# [800]	training's multi_logloss: 0.0720286	valid_1's multi_logloss: 0.197307
# [900]	training's multi_logloss: 0.0604741	valid_1's multi_logloss: 0.191443
# [1000]	training's multi_logloss: 0.0514342	valid_1's multi_logloss: 0.187091
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0514342	valid_1's multi_logloss: 0.187091
# ▶ Fold 8
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.313162	valid_1's multi_logloss: 0.351274
# [200]	training's multi_logloss: 0.231396	valid_1's multi_logloss: 0.286175
# [300]	training's multi_logloss: 0.183386	valid_1's multi_logloss: 0.251458
# [400]	training's multi_logloss: 0.149221	valid_1's multi_logloss: 0.230139
# [500]	training's multi_logloss: 0.12415	valid_1's multi_logloss: 0.215115
# [600]	training's multi_logloss: 0.103532	valid_1's multi_logloss: 0.203613
# [700]	training's multi_logloss: 0.0869656	valid_1's multi_logloss: 0.194335
# [800]	training's multi_logloss: 0.0735955	valid_1's multi_logloss: 0.187136
# [900]	training's multi_logloss: 0.0620007	valid_1's multi_logloss: 0.180964
# [1000]	training's multi_logloss: 0.0526388	valid_1's multi_logloss: 0.175897
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0526388	valid_1's multi_logloss: 0.175897
# ✅ play years AUC = 0.99031
#
# 📚 Training LightGBM for level...
# ▶ Fold 0
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.235167	valid_1's multi_logloss: 0.2824
# [200]	training's multi_logloss: 0.155516	valid_1's multi_logloss: 0.228272
# [300]	training's multi_logloss: 0.112881	valid_1's multi_logloss: 0.203487
# [400]	training's multi_logloss: 0.0849358	valid_1's multi_logloss: 0.18991
# [500]	training's multi_logloss: 0.0643535	valid_1's multi_logloss: 0.180623
# [600]	training's multi_logloss: 0.0493026	valid_1's multi_logloss: 0.174157
# [700]	training's multi_logloss: 0.0383965	valid_1's multi_logloss: 0.170881
# [800]	training's multi_logloss: 0.029446	valid_1's multi_logloss: 0.168532
# [900]	training's multi_logloss: 0.0227614	valid_1's multi_logloss: 0.167158
# Early stopping, best iteration is:
# [891]	training's multi_logloss: 0.0232687	valid_1's multi_logloss: 0.167001
# ▶ Fold 1
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.233976	valid_1's multi_logloss: 0.285871
# [200]	training's multi_logloss: 0.155651	valid_1's multi_logloss: 0.227884
# [300]	training's multi_logloss: 0.113989	valid_1's multi_logloss: 0.203428
# [400]	training's multi_logloss: 0.0853746	valid_1's multi_logloss: 0.188635
# [500]	training's multi_logloss: 0.0646403	valid_1's multi_logloss: 0.179256
# [600]	training's multi_logloss: 0.0496413	valid_1's multi_logloss: 0.173118
# [700]	training's multi_logloss: 0.0384854	valid_1's multi_logloss: 0.169363
# [800]	training's multi_logloss: 0.0300723	valid_1's multi_logloss: 0.166743
# [900]	training's multi_logloss: 0.0233381	valid_1's multi_logloss: 0.165235
# [1000]	training's multi_logloss: 0.0181356	valid_1's multi_logloss: 0.164088
# Did not meet early stopping. Best iteration is:
# [997]	training's multi_logloss: 0.0182674	valid_1's multi_logloss: 0.164054
# ▶ Fold 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.234739	valid_1's multi_logloss: 0.286638
# [200]	training's multi_logloss: 0.156237	valid_1's multi_logloss: 0.231054
# [300]	training's multi_logloss: 0.113063	valid_1's multi_logloss: 0.204945
# [400]	training's multi_logloss: 0.0838342	valid_1's multi_logloss: 0.189948
# [500]	training's multi_logloss: 0.0645072	valid_1's multi_logloss: 0.1804
# [600]	training's multi_logloss: 0.0496446	valid_1's multi_logloss: 0.174081
# [700]	training's multi_logloss: 0.0379638	valid_1's multi_logloss: 0.16929
# [800]	training's multi_logloss: 0.0293467	valid_1's multi_logloss: 0.166285
# [900]	training's multi_logloss: 0.0229622	valid_1's multi_logloss: 0.164498
# [1000]	training's multi_logloss: 0.0178192	valid_1's multi_logloss: 0.164016
# Did not meet early stopping. Best iteration is:
# [971]	training's multi_logloss: 0.0191938	valid_1's multi_logloss: 0.163863
# ▶ Fold 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.235515	valid_1's multi_logloss: 0.280969
# [200]	training's multi_logloss: 0.155099	valid_1's multi_logloss: 0.228459
# [300]	training's multi_logloss: 0.112624	valid_1's multi_logloss: 0.204958
# [400]	training's multi_logloss: 0.0846106	valid_1's multi_logloss: 0.191151
# [500]	training's multi_logloss: 0.0643632	valid_1's multi_logloss: 0.181903
# [600]	training's multi_logloss: 0.0496638	valid_1's multi_logloss: 0.175865
# [700]	training's multi_logloss: 0.0385197	valid_1's multi_logloss: 0.172144
# [800]	training's multi_logloss: 0.0297367	valid_1's multi_logloss: 0.169371
# [900]	training's multi_logloss: 0.0232724	valid_1's multi_logloss: 0.16757
# [1000]	training's multi_logloss: 0.0179615	valid_1's multi_logloss: 0.166833
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0179615	valid_1's multi_logloss: 0.166833
# ▶ Fold 4
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.236308	valid_1's multi_logloss: 0.270094
# [200]	training's multi_logloss: 0.156568	valid_1's multi_logloss: 0.211888
# [300]	training's multi_logloss: 0.113788	valid_1's multi_logloss: 0.185514
# [400]	training's multi_logloss: 0.0848553	valid_1's multi_logloss: 0.169229
# [500]	training's multi_logloss: 0.0648607	valid_1's multi_logloss: 0.158731
# [600]	training's multi_logloss: 0.0495792	valid_1's multi_logloss: 0.150632
# [700]	training's multi_logloss: 0.038053	valid_1's multi_logloss: 0.145493
# [800]	training's multi_logloss: 0.0295735	valid_1's multi_logloss: 0.14214
# [900]	training's multi_logloss: 0.0229784	valid_1's multi_logloss: 0.139424
# [1000]	training's multi_logloss: 0.0179077	valid_1's multi_logloss: 0.137792
# Did not meet early stopping. Best iteration is:
# [997]	training's multi_logloss: 0.0180426	valid_1's multi_logloss: 0.137727
# ▶ Fold 5
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.234643	valid_1's multi_logloss: 0.28195
# [200]	training's multi_logloss: 0.156153	valid_1's multi_logloss: 0.225991
# [300]	training's multi_logloss: 0.112686	valid_1's multi_logloss: 0.201652
# [400]	training's multi_logloss: 0.0838836	valid_1's multi_logloss: 0.187247
# [500]	training's multi_logloss: 0.064083	valid_1's multi_logloss: 0.177715
# [600]	training's multi_logloss: 0.0491394	valid_1's multi_logloss: 0.170589
# [700]	training's multi_logloss: 0.037898	valid_1's multi_logloss: 0.16624
# [800]	training's multi_logloss: 0.0291633	valid_1's multi_logloss: 0.162582
# [900]	training's multi_logloss: 0.0225787	valid_1's multi_logloss: 0.160743
# [1000]	training's multi_logloss: 0.0176967	valid_1's multi_logloss: 0.160007
# Did not meet early stopping. Best iteration is:
# [963]	training's multi_logloss: 0.0193865	valid_1's multi_logloss: 0.159799
# ▶ Fold 6
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.237095	valid_1's multi_logloss: 0.267062
# [200]	training's multi_logloss: 0.15707	valid_1's multi_logloss: 0.212191
# [300]	training's multi_logloss: 0.114646	valid_1's multi_logloss: 0.188828
# [400]	training's multi_logloss: 0.0861015	valid_1's multi_logloss: 0.174762
# [500]	training's multi_logloss: 0.0657857	valid_1's multi_logloss: 0.165258
# [600]	training's multi_logloss: 0.0503073	valid_1's multi_logloss: 0.159022
# [700]	training's multi_logloss: 0.0390098	valid_1's multi_logloss: 0.154736
# [800]	training's multi_logloss: 0.0301535	valid_1's multi_logloss: 0.151709
# [900]	training's multi_logloss: 0.0234302	valid_1's multi_logloss: 0.150208
# [1000]	training's multi_logloss: 0.0182567	valid_1's multi_logloss: 0.148979
# Did not meet early stopping. Best iteration is:
# [996]	training's multi_logloss: 0.0184239	valid_1's multi_logloss: 0.148965
# ▶ Fold 7
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.236178	valid_1's multi_logloss: 0.275161
# [200]	training's multi_logloss: 0.157615	valid_1's multi_logloss: 0.220903
# [300]	training's multi_logloss: 0.114007	valid_1's multi_logloss: 0.194514
# [400]	training's multi_logloss: 0.0857254	valid_1's multi_logloss: 0.17865
# [500]	training's multi_logloss: 0.0651182	valid_1's multi_logloss: 0.167383
# [600]	training's multi_logloss: 0.0499688	valid_1's multi_logloss: 0.160128
# [700]	training's multi_logloss: 0.0386345	valid_1's multi_logloss: 0.154361
# [800]	training's multi_logloss: 0.0296655	valid_1's multi_logloss: 0.150648
# [900]	training's multi_logloss: 0.0229988	valid_1's multi_logloss: 0.147846
# [1000]	training's multi_logloss: 0.0180274	valid_1's multi_logloss: 0.146371
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.0180274	valid_1's multi_logloss: 0.146371
# ▶ Fold 8
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.235888	valid_1's multi_logloss: 0.273225
# [200]	training's multi_logloss: 0.155547	valid_1's multi_logloss: 0.216039
# [300]	training's multi_logloss: 0.113035	valid_1's multi_logloss: 0.192418
# [400]	training's multi_logloss: 0.0849839	valid_1's multi_logloss: 0.177709
# [500]	training's multi_logloss: 0.0646271	valid_1's multi_logloss: 0.167177
# [600]	training's multi_logloss: 0.0489471	valid_1's multi_logloss: 0.159048
# [700]	training's multi_logloss: 0.0374444	valid_1's multi_logloss: 0.153882
# [800]	training's multi_logloss: 0.0290226	valid_1's multi_logloss: 0.150161
# [900]	training's multi_logloss: 0.022735	valid_1's multi_logloss: 0.148248
# [1000]	training's multi_logloss: 0.0175142	valid_1's multi_logloss: 0.146078
# Did not meet early stopping. Best iteration is:
# [998]	training's multi_logloss: 0.0176168	valid_1's multi_logloss: 0.146057
# ✅ level AUC = 0.99392

# %%
def build_swing_prediction_table(model, df, label_encoder, target_col, is_multiclass=False):
    """
    Returns a DataFrame with one row per swing prediction, including:
    - file_id
    - true_label
    - prediction vector (as list if multiclass, float if binary)
    """
    drop_cols = ['file_id', 'swing_id', 'gender', 'hold racket handed', 'play years', 'level']
    # Always drop the target column if it’s not already listed
    if target_col not in drop_cols:
        drop_cols.append(target_col)
    X = df.drop(columns=drop_cols)
    
    # Safety check to match feature count
    if X.shape[1] != model.num_feature():
        raise ValueError(f"[❌] Mismatch in feature count: X has {X.shape[1]} features, model expects {model.num_feature()}.")

    y = label_encoder.transform(df[target_col])
    preds = model.predict(X)

    swing_preds = []
    for i, file_id in enumerate(df['file_id']):
        row = {
            'file_id': file_id,
            'true_label': y[i],
            'pred': preds[i] if not is_multiclass else preds[i].tolist()
        }
        swing_preds.append(row)

    return pd.DataFrame(swing_preds)

# %%
from sklearn.model_selection import StratifiedKFold

def train_aggregator_model(pred_df, is_multiclass=False, n_splits=9):
    """
    Group swing-level predictions into (file_id, [27 preds])
    Train a LightGBM meta-model using CV to avoid overfitting
    """
    grouped = pred_df.groupby('file_id')

    X_meta = []
    y_meta = []

    for file_id, group in grouped:
        if is_multiclass:
            swing_preds = np.stack(group['pred'].values)
            features = swing_preds.flatten()
        else:
            features = group['pred'].values
        X_meta.append(features)
        y_meta.append(group['true_label'].iloc[0])

    X_meta = np.array(X_meta)
    y_meta = np.array(y_meta)

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    all_preds = np.zeros((len(X_meta), len(np.unique(y_meta))) if is_multiclass else len(X_meta))

    for fold, (train_idx, val_idx) in enumerate(skf.split(X_meta, y_meta)):
        X_train, X_val = X_meta[train_idx], X_meta[val_idx]
        y_train, y_val = y_meta[train_idx], y_meta[val_idx]

        model_cv = lgb.LGBMClassifier(
            objective='multiclass' if is_multiclass else 'binary',
            num_class=len(np.unique(y_meta)) if is_multiclass else None,
            random_state=42
        )
        model_cv.fit(X_train, y_train)

        preds_val = model_cv.predict_proba(X_val)
        if is_multiclass:
            all_preds[val_idx] = preds_val
        else:
            all_preds[val_idx] = preds_val[:, 1]

    if is_multiclass:
        score = roc_auc_score(y_meta, all_preds, multi_class='ovr')
    else:
        score = roc_auc_score(y_meta, all_preds)

    print(f"✅ Aggregation model CV AUC = {score:.5f}")

    # Train final model on all data (used for inference later)
    final_model = lgb.LGBMClassifier(
        objective='multiclass' if is_multiclass else 'binary',
        num_class=len(np.unique(y_meta)) if is_multiclass else None,
        random_state=42
    )
    final_model.fit(X_meta, y_meta)

    return final_model

# %%
def train_pipeline_for_label(swing_df, model, label_encoder, target_col, is_multiclass, n_splits=9):
    swing_preds = build_swing_prediction_table(
        model=model,
        df=swing_df,
        label_encoder=label_encoder,
        target_col=target_col,
        is_multiclass=is_multiclass,
    )
    meta_model = train_aggregator_model(
        pred_df=swing_preds,
        is_multiclass=is_multiclass,
        n_splits = n_splits,
    )
    return swing_preds, meta_model

# %%
# --- 1. Gender (already done) ---
swing_pred_gender, meta_gender_model = train_pipeline_for_label(swing_df, model_gender, le_gender, target_col='gender', is_multiclass=False)
# Out:
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ✅ Aggregation model CV AUC = 1.00000
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
# --- 2. Hold Racket Handed ---
swing_pred_hand, meta_hand_model = train_pipeline_for_label(swing_df, model_hand, le_hand, target_col='hold racket handed', is_multiclass=False)
# Out:
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ✅ Aggregation model CV AUC = 1.00000
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
# --- 3. Play Years ---
swing_pred_years, meta_years_model = train_pipeline_for_label(swing_df, model_years, le_years, target_col='play years', is_multiclass=True)
# Out:
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ✅ Aggregation model CV AUC = 1.00000

# %%
# 4. Build swing-level predictions and train meta-model for level
swing_pred_level, meta_level_model = train_pipeline_for_label(
    swing_df, model_level, le_level, target_col='level', is_multiclass=True
)
# Out:
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Gish.AI\.conda\envs\AIcup_2025\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ✅ Aggregation model CV AUC = 1.00000

# %%
def predict_file(file_path, cut_point_str, mode, model_swing, model_meta, is_multiclass=False):
    from numpy import fromstring

    # Step 1: parse cut points
    cut_points = np.fromstring(cut_point_str.strip("[]"), sep=' ', dtype=int).tolist()

    # Step 2: load sensor data
    with open(file_path, 'r') as f:
        lines = f.readlines()[1:]
    data = np.array([list(map(int, line.strip().split())) for line in lines if len(line.strip().split()) == 6])

    # Step 3: per-swing feature extraction
    swings = [data[cut_points[i]:cut_points[i+1]] for i in range(len(cut_points) - 1)]
    feature_rows = []
    for swing in swings:
        row = extract_features_from_swing(swing)
        for m in range(1, 11):
            row[f'mode_{m}'] = 1 if mode == m else 0
        feature_rows.append(row)

    df = pd.DataFrame(feature_rows)
    X = df.values

    # Step 4: swing-level prediction
    preds = model_swing.predict(X)
    if is_multiclass:
        swing_preds = np.stack(preds)
        meta_input = swing_preds.flatten().reshape(1, -1)
    else:
        swing_preds = preds  # shape (27,)
        meta_input = np.array(swing_preds).reshape(1, -1)

    # Step 5: wrap meta_input in DataFrame with feature names to suppress warning
    meta_input_df = pd.DataFrame(meta_input, columns=[f'swing_{i}' for i in range(meta_input.shape[1])])
    prob = model_meta.predict_proba(meta_input_df)[0]

    return prob if is_multiclass else prob[1]

# %%
def run_test_pipeline():
    test_info = pd.read_csv("39_Test_Dataset/test_info.csv")
    test_folder = Path("39_Test_Dataset/test_data")

    gender_preds = []
    hand_preds = []
    play_years_preds = []
    level_preds = []  # ← Add this line

    for file_path in tqdm(sorted(test_folder.glob("*.txt")), desc="🎯 Predicting test"):
        uid = int(file_path.stem)
        row = test_info[test_info['unique_id'] == uid]
        cut_str = row['cut_point'].values[0]
        mode = row['mode'].values[0]

        pred_gender = predict_file(file_path, cut_str, mode, model_gender, meta_gender_model, is_multiclass=False)
        pred_hand = predict_file(file_path, cut_str, mode, model_hand, meta_hand_model, is_multiclass=False)
        pred_years = predict_file(file_path, cut_str, mode, model_years, meta_years_model, is_multiclass=True)
        pred_level = predict_file(file_path, cut_str, mode, model_level, meta_level_model, is_multiclass=True)

        gender_preds.append(pred_gender)
        hand_preds.append(pred_hand)
        play_years_preds.append(pred_years)
        level_preds.append(pred_level)  # ← This now works

    return test_info['unique_id'].values, gender_preds, hand_preds, play_years_preds, level_preds

# %%
from datetime import datetime

def save_submission(uids, gender_preds, hand_preds, play_years_preds, level_preds):
    submission = pd.DataFrame()
    submission['unique_id'] = uids
    submission['gender'] = gender_preds
    submission['hold racket handed'] = hand_preds

    # play years (no shift needed)
    for i in range(len(play_years_preds[0])):
        submission[f'play years_{i}'] = [p[i] for p in play_years_preds]

    # level (shift class index by +2)
    for i in range(len(level_preds[0])):
        submission[f'level_{i+2}'] = [p[i] for p in level_preds]

    # Pad missing columns
    sample = pd.read_csv("39_Test_Dataset/sample_submission.csv")
    for col in sample.columns:
        if col not in submission.columns:
            submission[col] = 0.0

    submission = submission[sample.columns]

    # Add timestamp to filename
    timestamp = datetime.now().strftime("%Y%m%d_%H%M")
    filename = f"submission_{timestamp}.csv"

    submission.to_csv(filename, index=False, float_format='%.10f')
    print(f"✅ {filename} saved.")

# %%
uids, g_preds, h_preds, y_preds, l_preds = run_test_pipeline()
# Out:
# 🎯 Predicting test: 100%|██████████████████████████████████████████████████████████| 1430/1430 [02:24<00:00,  9.89it/s]

# %%
save_submission(uids, g_preds, h_preds, y_preds, l_preds)
# Out:
# ✅ submission_20250430_1047.csv saved.
